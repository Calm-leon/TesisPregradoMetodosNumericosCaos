# %% [markdown]
# ### Importaciones

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy import symbols, Function, dsolve, exp, sin, pi, tan, sympify

# %% [markdown]
# ### Definicion de la funcion

# %%
def funcion_f(ecuacion:str="x"):
    function = sp.sympify(ecuacion)
    return function

# %%
m = (np.tan(3/20))/np.e
n = (np.tan(301/2000))/np.e
p = (np.tan(151/1000))/np.e

# %%
# Definir el símbolo t
t = sp.symbols('t')
c = -3.15
# Definir la función simbólica
funcion_simbolica1 = 2 * sp.atan(m * sp.exp(sp.exp((t))))
funcion_simbolica2 = 2 * sp.atan(n * sp.exp(sp.exp(t)))
funcion_simbolica3 = 2 * sp.atan(p * sp.exp(sp.exp(t)))
funcion_simbolica4 = 2 * sp.atan(0 * sp.exp(sp.exp(t)))
funcion_simbolica5 = 2 * sp.atan((c+1) * sp.exp(sp.exp(t)))
funcion_simbolica6 = 2 * sp.atan((c+2) * sp.exp(sp.exp(t)))
funcion_simbolica7 = 2 * sp.atan((c+3) * sp.exp(sp.exp(t)))
funcion_simbolica8 = 2 * sp.atan((c+4) * sp.exp(sp.exp(t)))
funcion_simbolica9 = 2 * sp.atan((c+5) * sp.exp(sp.exp(t)))
funcion_simbolica10 = 2 * sp.atan((c+6) * sp.exp(sp.exp(t)))

# %% [markdown]
# *Digite el numero de iteraciones deseadas:*

# %%
numero_iteraciones = 8

# %% [markdown]
# *Digite el valor inicial en t:*

# %%
paso_inicial_T = -4

# %% [markdown]
# *Digite el valor final en t:*

# %%
paso_final_T = 4

# %% [markdown]
# *Digite la condicion inicial de $x(t)$:*

# %% [markdown]
# *A continuación calcularemos el $\Delta t$*

# %%
delta_T = (paso_final_T - paso_inicial_T)/numero_iteraciones
delta_T
# Out:
# 1.0

# %% [markdown]
# ### Iniciemos con la solucion exacta

# %%
# Creamos una lista con un solo elemento de nuestro valore inicial de t
vector_T_funcion_real = np.array([paso_inicial_T])
        
# Iteramos para crear el vector para realizar la graficación de la funcion exacta
for iteracion in range(numero_iteraciones*100):
    t_i = (vector_T_funcion_real[iteracion] + delta_T/ 100) 
    vector_T_funcion_real = np.append(vector_T_funcion_real, t_i)

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion1 = [funcion_simbolica1.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion2 = [funcion_simbolica2.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion3 = [funcion_simbolica3.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion4 = [funcion_simbolica4.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion5 = [funcion_simbolica5.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion6 = [funcion_simbolica6.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion7 = [funcion_simbolica7.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion8 = [funcion_simbolica8.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion9 = [funcion_simbolica9.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %%
# Evaluamos la función en cada valor de tiempo y almacenamos los resultados en una lista
vector_f_solucion10 = [funcion_simbolica10.subs({t: valor}) for valor in list(vector_T_funcion_real)]

# %% [markdown]
# ### Grafica trajando

# %%
colores = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
colores_intensos = ['#FF355E', '#FD5B78', '#FF6037', '#FF9966', '#FF9933', '#FFCC33', '#FFFF66', '#CCFF00', '#66FF66', '#AAF0D1']
colores_intensos = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
plt.figure(figsize=(8, 6))
plt.text(-5.6, 0, 'x(t)', rotation='horizontal', fontsize=12)  # Colocar 'x(t)' verticalmente
plt.xticks(np.arange(-4, 5, 1))  # Marcas cada unidad en el eje x
plt.yticks(np.arange(-3.14, 4.14, 0.5))  # Marcas cada unidad en el eje y
plt.grid(True, linewidth=0.3)  # Ajusta el ancho de las líneas de la cuadrícula
plt.axhline(0, color='black', linewidth=0.8)  # Línea horizontal en y=0
plt.axvline(0, color='black', linewidth=0.8)  # Línea vertical en x=0
plt.xlabel('$t$')
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion1,
    label="0.300",
    color='navy',
    linestyle='-',
    linewidth=0.9,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion2,
    label="0.301",
    color='orange',
    linestyle='-.',
    alpha = 0.6,
    linewidth=1.1,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion3,
    label="0.302",
    color="purple",
    linestyle='--',
    alpha = 0.4,
    linewidth=1.2,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion4,
    label="0",
    color='blue',
    linestyle='-',
    alpha = 0.4,
    linewidth=1.3,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion5,
    color=colores_intensos[5],
    linestyle='-',
    linewidth=0.9,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion6,
    color=colores_intensos[4],
    linestyle='-',
    alpha = 0.6,
    linewidth=1.1,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion7,
    color=colores_intensos[3],
    linestyle='-',
    alpha = 0.4,
    linewidth=0.9,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion8,
    color=colores_intensos[2],
    linestyle='-',
    alpha = 0.4,
    linewidth=0.9,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion9,
    color=colores_intensos[1],
    linestyle='-',
    alpha = 0.4,
    linewidth=0.9,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real,
    vector_f_solucion10,
    color=colores_intensos[0],
    linestyle='-',
    alpha = 0.4,
    linewidth=0.9,
    markersize=12, 
)
plt.legend()  # Esto coloca la leyenda en la esquina superior izquierda
plt.title("Familia de soluciones")
plt.savefig("Familia de soluciones.pdf")  # Con esta se guarda la imagen en formato pdf
plt.show()

# %%
plt.plot(
    vector_T_funcion_real[400:410],
    vector_f_solucion1[400:410],
    label="0.3",
    color='darkgreen',
    linestyle='-.',
    linewidth=0.9,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real[400:410],
    vector_f_solucion2[400:410],
    label="0.301",
    color='darkred',
    linestyle='-.',
    alpha = 0.6,
    linewidth=1.1,
    markersize=12, 
)
plt.plot(
    vector_T_funcion_real[400:410],
    vector_f_solucion3[400:410],
    label="0.302",
    color='navy',
    linestyle='-',
    alpha = 0.4,
    linewidth=0.9,
    markersize=12, 
)
